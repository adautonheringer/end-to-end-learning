# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import cv2
from PIL import Image

# %%
DATADIR = '/home/adauton/Documents/Mestrado/Tese/PythonAPI/dataset'

data = np.load(DATADIR+'/00001664.npz')
#cv2.imshow(data['x'], )

print(data.files)
#cv2.namedWindow('RGB Camera', cv2.WINDOW_AUTOSIZE)
#cv2.imshow('RGB Camera', data[0])
image = data['x']
label = data['y']
print(label)
print(image.shape)
plt.imshow(image)
plt.show()

im = Image.fromarray(image)
im.save('myImage3434.png')
# Out:
# ['x', 'y']
# [0.75       0.         0.05377135]
# (720, 1280, 3)
